# %% [markdown]
# ## Connect to ICW:

# %%
from math import sqrt
import cadspy
import numpy as np
import pandas as pd
from datetime import datetime as dt
from itertools import combinations
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, KFold, cross_val_score
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error


# diplay all rows and cols when using 'dataframe'.head() or 'dataframe'.tail()
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
icw = cadspy.DatabaseConnection(system='ICW', user='n518899')

# %% [markdown]
# <br>
#
# ### Data
#
# #### S19 Lounge Eligibility data

# %%
# lounge eligibility data
query = """

sel * from LDB_SBOX_OR.HACKATHON_OPS_LOUNGE_ELIGIBILITY

"""

df_lounge_eligibility = icw.queryToDataframe(query)

# flight info data
query = """

select * from LDB_SBOX_OR.HACKATHON_OPS_FLIGHT_INFO

"""

df_flight_info = icw.queryToDataframe(query)

# country decode data
query = """

select * from LDB_SBOX_OR.HACKATHON_OPS_COUNTRY_DECODE

"""

df_country = icw.queryToDataframe(query)

# AC_type
query = """

select * from LDB_SBOX_OR.HACKATHON_OPS_AC_TYPE

"""

df_acft_typ = icw.queryToDataframe(query)

geo_query = """
SELECT 
	* 
FROM 
	LUV_ALL.B_REF_RAS_GEOGRAPHY RRG_O
	
WHERE
	RRG_O.STN_CD <> ''
"""

df_geo = icw.queryToDataframe(geo_query)

df_cap_city = pd.read_csv('https://raw.githubusercontent.com/icyrockcom/country-capitals/master/data/country-list.csv')

# %% [markdown]
# <br>
#
# ### Pre-processing

# %% [markdown]
# *Hint:* It is always worth checking the format of each of the columns in your dataframes before trying to do any work with them. To do so, you can make use of the `headers_and_first_row` function below.

# %%
def headers_and_first_row(df):
    '''
    print headers and first row of a df to deal with data types
    '''
    
    headers = df.columns
    first_row = []

    for col in headers:
        first_row.append(df[col][0])
    
    dictionary = dict( zip( headers, first_row) )

    return dictionary

# helper function

def dataframe_str_formatter(df):
    '''Strips all whitespace in string columns in DataFrame'''
    for col in df.columns:
        if isinstance(df[col][0],str):
            df[col] = df[col].str.strip()
        else:
            continue
    return df

# %%
# applying headers_and_first_row to df_lounge_eligibility
format_df = headers_and_first_row(df_lounge_eligibility)

# Note that some columns have blank spaces!
format_df
# Out:
# {'OPERATING_AIRLINE_CD': 'BA    ',
#  'OPERATING_FLT_NO': 57,
#  'GMT_UPLIFT_DT': datetime.date(2019, 6, 18),
#  'UPLIFT_STN_CD': 'LHR   ',
#  'DISCHARGE_STN_CD': 'JNB   ',
#  'BOOKED_CABIN_CD': 'J ',
#  'TRAVEL_CABIN_CD': 'J ',
#  'BA_PAX_TIER': '',
#  'ONEWORLD_TIER': 'EMER',
#  'Lounge_eligibility_tier': 'Tier 2',
#  'pax': 1}

# %%
# pre-processing code

df_lounge_eligibility = dataframe_str_formatter(df_lounge_eligibility)
df_lounge_eligibility['GMT_UPLIFT_DT'] = pd.to_datetime(df_lounge_eligibility['GMT_UPLIFT_DT'])

# %% [markdown]
# <br><br>

# %% [markdown]
# ### df_flight_info pre-processing

# %%
format_df = headers_and_first_row(df_flight_info)

format_df
# Out:
# {'OPG_ALN_CD': 'BA    ',
#  'OPG_FLT_NO': 548,
#  'GMT_PLND_DEP_TS': Timestamp('2019-06-03 07:30:00'),
#  'GMT_ACT_DEP_TS': Timestamp('2019-06-03 07:27:00'),
#  'ACT_DEP_STN_CD': 'LHR   ',
#  'ACT_DEP_TML_CD': '5 ',
#  'PLND_ARR_STN_CD': 'FCO   ',
#  'ACT_ARR_STN_CD': 'FCO   ',
#  'IATA_AC_TYP_CD': '321   ',
#  'ACT_AC_TYP_CD': 'V6  ',
#  'ROUTE': 'LHRFCO      ',
#  'COUNTRY_CD': 'IT    ',
#  'COUNTRY_NM': 'Italy',
#  'CORP_GEOG_CTRY_GRP_NM': 'MEDITERRANEAN',
#  'CORP_GEOG_CONTINENT_NM': 'EUROPE EXC UK'}

# %%
# pre-processing code

df_flight_info = dataframe_str_formatter(df_flight_info)

# Need to convert to same date type for merge
df_flight_info['GMT_PLND_DEP_TS'] = pd.to_datetime(df_flight_info['GMT_PLND_DEP_TS'], format = '%Y-%m-%d')
df_flight_info['GMT_PLND_DEP'] = pd.to_datetime(df_flight_info['GMT_PLND_DEP_TS'].dt.date)

format_df = headers_and_first_row(df_flight_info)

format_df
# Out:
# {'OPG_ALN_CD': 'BA',
#  'OPG_FLT_NO': 548,
#  'GMT_PLND_DEP_TS': Timestamp('2019-06-03 07:30:00'),
#  'GMT_ACT_DEP_TS': Timestamp('2019-06-03 07:27:00'),
#  'ACT_DEP_STN_CD': 'LHR',
#  'ACT_DEP_TML_CD': '5',
#  'PLND_ARR_STN_CD': 'FCO',
#  'ACT_ARR_STN_CD': 'FCO',
#  'IATA_AC_TYP_CD': '321',
#  'ACT_AC_TYP_CD': 'V6',
#  'ROUTE': 'LHRFCO',
#  'COUNTRY_CD': 'IT',
#  'COUNTRY_NM': 'Italy',
#  'CORP_GEOG_CTRY_GRP_NM': 'MEDITERRANEAN',
#  'CORP_GEOG_CONTINENT_NM': 'EUROPE EXC UK',
#  'GMT_PLND_DEP': Timestamp('2019-06-03 00:00:00')}

# %% [markdown]
# ### df_country pre-processing

# %%
# show current format

format_df_country = headers_and_first_row(df_country)

format_df_country

# pre-processing code

df_country = dataframe_str_formatter(df_country)

format_df_country = headers_and_first_row(df_country)

format_df_country
# Out:
# {'ROUTE': 'LHRINV',
#  'COUNTRY_CD': 'GB',
#  'COUNTRY_NM': 'United Kingdom and Northern Ireland',
#  'CORP_GEOG_CTRY_GRP_NM': 'UK',
#  'CORP_GEOG_CONTINENT_NM': 'UK'}

# %% [markdown]
# ### df_acft_type pre-processing

# %%
# show current format

format_df_aircraft = headers_and_first_row(df_acft_typ)

format_df_aircraft

# pre-processing code

df_acft_type = dataframe_str_formatter(df_acft_typ)

format_df_aircraft = headers_and_first_row(df_acft_typ)

format_df_aircraft
# Out:
# {'IATA_AC_TYP_CD': '320',
#  'ACT_AC_TYP_CD': 'A3',
#  'WB_NB_CAT': 'NB',
#  'FIRST_SEATS_QTY': 0,
#  'CLUB_SEATS_QTY': 24,
#  'PREM_ECONOMY_SEATS_QTY': 0,
#  'ECONOMY_SEATS_QTY': 132}

# %%
format_df_geo = headers_and_first_row(df_geo)

format_df_geo

# pre-processing code

df_geo = dataframe_str_formatter(df_geo)

# %%
# Example

# joining df_lounge_eligibility and df_flight_info

df_lounge_elig_flight_info = pd.merge(df_lounge_eligibility,# left table
                                     df_flight_info, # right table
                                     left_on = ['GMT_UPLIFT_DT','OPERATING_FLT_NO','UPLIFT_STN_CD','DISCHARGE_STN_CD'], # left on? e.g. which columns from the left table are you joining on to?
                                     right_on = ['GMT_PLND_DEP','OPG_FLT_NO','ACT_DEP_STN_CD','ACT_ARR_STN_CD'], # right on? # left on? e.g. which columns from the right table are you joining on to?
                                     how = "left" # how? e.g. left, right, inner,etc
                                     )

print('Old Shape: {}'.format(df_lounge_eligibility.shape))
print('New Shape: {}'.format(df_lounge_elig_flight_info.shape))
# Out:
# Old Shape: (973878, 11)
# New Shape: (973878, 27)

# %% [markdown]
# ### Check Join has worked correctly by looking at some rows and countings null where join may not have worked

# %%
# your code here!

df_lounge_country_flight = pd.merge(df_lounge_elig_flight_info,
                                   df_country,
                                   on = 'ROUTE',
                                   how = 'left'
                                   )

print('Old Shape: {}'.format(df_lounge_elig_flight_info.shape))
print('New Shape: {}'.format(df_lounge_country_flight.shape))
# Out:
# Old Shape: (973878, 27)
# New Shape: (973878, 31)

# %%
df_lounge_country_geo = pd.merge(df_lounge_country_flight,
                                   df_geo,
                                   left_on = 'DISCHARGE_STN_CD',
                                   right_on = 'STN_CD',
                                   how = 'left'
                                   )

print('Old Shape: {}'.format(df_lounge_country_flight.shape))
print('New Shape: {}'.format(df_lounge_country_geo.shape))
# Out:
# Old Shape: (973878, 31)
# New Shape: (1027226, 44)

# %%
df_pen = pd.merge(df_lounge_country_geo,
                   df_acft_typ,
                   on = ['IATA_AC_TYP_CD','ACT_AC_TYP_CD'],
                   how = 'left'

                   )

print('Old Shape: {}'.format(df_lounge_country_flight.shape))
print('New Shape: {}'.format(df_pen.shape))
# Out:
# Old Shape: (973878, 31)
# New Shape: (1027226, 49)

# %%
df_final = pd.merge(df_pen,
                   df_cap_city,
                   left_on = ['CITY_NM'],
                   right_on = ['capital'],
                   how = 'left'
                   )

print('Old Shape: {}'.format(df_pen.shape))
print('New Shape: {}'.format(df_final.shape))
# Out:
# Old Shape: (1027226, 49)
# New Shape: (1027226, 52)

# %% [markdown]
# <br><br><br>

# %%
#--------------------------------
#
# Your turn!!!
#
#--------------------------------

# %% [markdown]
# <u>What level of granularity do you use?</u>
#
# This project wants to understand what characteristics of a flight help us get a better picture of the lounge eligibility profiles.
# Things I want to consider:
# - Time of flight (Morning, Afternoon, Evening) or maybe even by hour
# - Destination as this determines the passenger profile, different countries/regions have more premium passengers potentially
# - Short Haul/Medium Haul/Long Haul
# - Month of Flight
# - City Route Flag
# - Weekday/Weekend
# - Business Route indicator?
#
#
# <u>General Thoughts:</u>
#
# Destination:
# - Routes are too granular as if we have new routes in the future we wouldn't be able to estimate
# - Countries could also be granular if we develop new routes to countries
# - Region may be suited as we currently fly to all regions
# - We need to think how to consider how certain countries within a region may have higher premium loads vs others
#
# <u>What metric do you use to come up with Lounge eligibility profiles?</u>
# - ... (your answer here)

# %% [markdown]
# ## Key Functions

# %% [markdown]
# #### Proportion Table Function

# %%
df_final.sample(10)
# Out:
#        OPERATING_AIRLINE_CD  OPERATING_FLT_NO GMT_UPLIFT_DT UPLIFT_STN_CD  \
# 250902                   BA               223    2019-09-08           LHR
# 978463                   BA               364    2019-08-10           LHR
# 87217                    BA               157    2019-09-08           LHR
# 698080                   BA               410    2019-08-30           LHR
# 718561                   BA              1402    2019-09-26           LHR
# 128776                   BA              1438    2019-05-09           LHR
# 914914                   BA               195    2019-08-24           LHR
# 554997                   BA               814    2019-10-03           LHR
# 870274                   BA               374    2019-07-20           LHR
# 262712                   BA                85    2019-05-06           LHR
#
#        DISCHARGE_STN_CD BOOKED_CABIN_CD TRAVEL_CABIN_CD BA_PAX_TIER  \
# 250902              BNA               J               J
# 978463              LYS               M               M
# 87217               KWI               J               J        Gold
# 698080              IBZ               M               M
# 718561              MAN               M               M
# 128776              EDI               C               C        Gold
# 914914              IAH               J               J
# 554997              CPH               M               M        Gold
# 870274              TLS               M               M        Gold
# 262712              YVR               F               F        Gold
#
#        ONEWORLD_TIER Lounge_eligibility_tier  pax OPG_ALN_CD  OPG_FLT_NO  \
# 250902          EMER                  Tier 2    3         BA       223.0
# 978463                          Not eligible  137         BA       364.0
# 87217           EMER                  Tier 2    3         BA       157.0
# 698080          SAPP                  Tier 3    1         BA       410.0
# 718561                          Not eligible   81         BA      1402.0
# 128776          EMER                  Tier 2    2         BA      1438.0
# 914914          SAPP                  Tier 3    1         BA       195.0
# 554997                                Tier 2    1         BA       814.0
# 870274                                Tier 2    1         BA       374.0
# 262712                                Tier 1    2         BA        85.0
#
#            GMT_PLND_DEP_TS      GMT_ACT_DEP_TS ACT_DEP_STN_CD ACT_DEP_TML_CD  \
# 250902 2019-09-08 13:55:00 2019-09-08 13:52:00            LHR              5
# 978463 2019-08-10 19:20:00 2019-08-10 21:27:00            LHR              3
# 87217  2019-09-08 20:55:00 2019-09-08 21:05:00            LHR              5
# 698080 2019-08-30 07:40:00 2019-08-30 07:40:00            LHR              5
# 718561 2019-09-26 17:15:00 2019-09-26 18:55:00            LHR              5
# 128776 2019-05-09 08:15:00 2019-05-09 08:13:00            LHR              5
# 914914 2019-08-24 08:55:00 2019-08-24 09:05:00            LHR              5
# 554997 2019-10-03 08:55:00 2019-10-03 08:52:00            LHR              5
# 870274 2019-07-20 15:10:00 2019-07-20 15:35:00            LHR              5
# 262712 2019-05-06 16:20:00 2019-05-06 16:19:00            LHR              3
#
#        PLND_ARR_STN_CD ACT_ARR_STN_CD IATA_AC_TYP_CD ACT_AC_TYP_CD   ROUTE  \
# 250902             BNA            BNA            789            L8  LHRBNA
# 978463             LYS            LYS            320            A3  LHRLYS
# 87217              KWI            KWI            777            V7  LHRKWI
# 698080             IBZ            IBZ            321            V6  LHRIBZ
# 718561             MAN            MAN            319            A4  LHRMAN
# 128776             EDI            EDI            319            A4  LHREDI
# 914914             IAH            IAH            744            S4  LHRIAH
# 554997             CPH            CPH            321            V6  LHRCPH
# 870274             TLS            TLS            321            V6  LHRTLS
# 262712             YVR            YVR            388            A8  LHRYVR
#
#        COUNTRY_CD_x                         COUNTRY_NM_x  \
# 250902           US                        United States
# 978463           FR                               France
# 87217            KW                               Kuwait
# 698080           ES                                Spain
# 718561           GB  United Kingdom and Northern Ireland
# 128776           GB  United Kingdom and Northern Ireland
# 914914           US                        United States
# 554997           DK                              Denmark
# 870274           FR                               France
# 262712           CA                               Canada
#
#        CORP_GEOG_CTRY_GRP_NM_x CORP_GEOG_CONTINENT_NM_x GMT_PLND_DEP  \
# 250902                     USA            NORTH AMERICA   2019-09-08
# 978463             WEST EUROPE            EUROPE EXC UK   2019-08-10
# 87217            NORTHERN GULF              MIDDLE EAST   2019-09-08
# 698080             WEST EUROPE            EUROPE EXC UK   2019-08-30
# 718561                      UK                       UK   2019-09-26
# 128776                      UK                       UK   2019-05-09
# 914914                     USA            NORTH AMERICA   2019-08-24
# 554997             SCANDINAVIA            EUROPE EXC UK   2019-10-03
# 870274             WEST EUROPE            EUROPE EXC UK   2019-07-20
# 262712                  CANADA            NORTH AMERICA   2019-05-06
#
#        COUNTRY_CD_y                         COUNTRY_NM_y  \
# 250902           US                        United States
# 978463           FR                               France
# 87217            KW                               Kuwait
# 698080           ES                                Spain
# 718561           GB  United Kingdom and Northern Ireland
# 128776           GB  United Kingdom and Northern Ireland
# 914914           US                        United States
# 554997           DK                              Denmark
# 870274           FR                               France
# 262712           CA                               Canada
#
#        CORP_GEOG_CTRY_GRP_NM_y CORP_GEOG_CONTINENT_NM_y CTRY_CD  CTRY_NM  \
# 250902                     USA            NORTH AMERICA      US      USA
# 978463             WEST EUROPE            EUROPE EXC UK      FR   France
# 87217            NORTHERN GULF              MIDDLE EAST      KW   Kuwait
# 698080             WEST EUROPE            EUROPE EXC UK      ES    Spain
# 718561                      UK                       UK      GB       UK
# 128776                      UK                       UK      GB       UK
# 914914                     USA            NORTH AMERICA      US      USA
# 554997             SCANDINAVIA            EUROPE EXC UK      DK  Denmark
# 870274             WEST EUROPE            EUROPE EXC UK      FR   France
# 262712                  CANADA            NORTH AMERICA      CA   Canada
#
#        REGION_CD  REGION_NM SUB_REGION_CD    SUB_REGION_NM STN_CD  \
# 250902         2  N America            UT   US Territories    BNA
# 978463         1     Europe            WE         W Europe    LYS
# 87217          3      AMESA            ME             MECA    KWI
# 698080         1     Europe            WE         W Europe    IBZ
# 718561         1     Europe            WE         W Europe    MAN
# 128776         1     Europe            WE         W Europe    EDI
# 914914         2  N America            UT   US Territories    IAH
# 554997         1     Europe            NE         N Europe    CPH
# 870274         1     Europe            WE         W Europe    TLS
# 262712         2  N America            MO  N America Other    YVR
#
#                                       STN_NM CITY_CD     CITY_NM SUB_CTRY_CD  \
# 250902                             Nashville     BNA   Nashville        None
# 978463                                  Lyon     LYS        Lyon        None
# 87217                                 Kuwait     KWI      Kuwait        None
# 698080                                 Ibiza     IBZ       Ibiza        BA
# 718561                            Manchester     MAN  Manchester        EN
# 128776                             Edinburgh     EDI   Edinburgh        SC
# 914914  Houston George Bush Intercontinental     HOU     Houston        None
# 554997                            Copenhagen     CPH  Copenhagen        None
# 870274                      Toulouse Blagnac     TLS    Toulouse        None
# 262712                             Vancouver     YVR   Vancouver        None
#
#        SUB_CTRY_NM                                          ICW_TX_PD  \
# 250902        None  2017-10-31 05:04:13.000000,9999-12-31 23:59:59...
# 978463        None  2017-02-28 13:42:06.000000,9999-12-31 23:59:59...
# 87217         None  2017-02-28 13:42:06.000000,9999-12-31 23:59:59...
# 698080    Baleares  2017-02-28 13:42:06.000000,9999-12-31 23:59:59...
# 718561     England  2017-02-28 13:42:06.000000,9999-12-31 23:59:59...
# 128776    Scotland  2017-02-28 13:42:06.000000,9999-12-31 23:59:59...
# 914914        None  2017-02-28 13:42:06.000000,9999-12-31 23:59:59...
# 554997        None  2017-02-28 13:42:06.000000,9999-12-31 23:59:59...
# 870274        None  2017-02-28 13:42:06.000000,9999-12-31 23:59:59...
# 262712        None  2017-02-28 13:42:06.000000,9999-12-31 23:59:59...
#
#        WB_NB_CAT  FIRST_SEATS_QTY  CLUB_SEATS_QTY  PREM_ECONOMY_SEATS_QTY  \
# 250902        WB              8.0            42.0                    39.0
# 978463        NB              0.0            24.0                     0.0
# 87217         WB             14.0            48.0                    40.0
# 698080        NB              0.0            38.0                     0.0
# 718561        NB              0.0            16.0                     0.0
# 128776        NB              0.0            16.0                     0.0
# 914914        WB             14.0            86.0                    30.0
# 554997        NB              0.0            38.0                     0.0
# 870274        NB              0.0            38.0                     0.0
# 262712        WB             14.0            97.0                    55.0
#
#         ECONOMY_SEATS_QTY   country     capital            type
# 250902              127.0       NaN         NaN             NaN
# 978463              132.0       NaN         NaN             NaN
# 87217               124.0       NaN         NaN             NaN
# 698080              160.0       NaN         NaN             NaN
# 718561              119.0       NaN         NaN             NaN
# 128776              119.0  Scotland   Edinburgh  countryCapital
# 914914              145.0       NaN         NaN             NaN
# 554997              160.0   Denmark  Copenhagen  countryCapital
# 870274              160.0       NaN         NaN             NaN
# 262712              303.0       NaN         NaN             NaN

# %%
def tier_proportions(features, df_fin):
    
    '''A function to build our the proportion of customers eligible for lounge based on features inputted'''

    tier_col = 'Lounge_eligibility_tier'
    
    # Create group by parameters
    groupby_list = features[:]
    groupby_list.append(tier_col)

    # Get total eligible by features and tier
    df_grouped = df_fin.groupby(groupby_list).agg({'pax':'sum'})

    # Add total amount for features excluding tier to get breakdown
    df_grouped['total_pax_features'] = df_grouped.groupby(features)['pax'].transform('sum')

    # proportion elgible 
    df_grouped['proportion'] = (df_grouped['pax'] / df_grouped['total_pax_features']) * 100
    df_grouped['proportion'] = df_grouped['proportion'].map('{:,.1f}%'.format)

    # reset index
    df_grouped.reset_index(inplace = True)

    # remove not eligible passengers
    df_grouped = df_grouped[df_grouped[tier_col] != 'Not eligible']

    # reshape data required for Ops Team
    df = df_grouped.pivot(index = features, columns = tier_col, values = 'proportion')
    
    return df

# %% [markdown]
# <br>
#
# Please save your final lookup table below in the form of a pandas dataframe. It must contain the categories you have come up with as rows, and the Tier 1, Tier 2, and Tier 3 percentage of costumers as columns.

# %% [markdown]
# #### Evaluation Function

# %%
# Build out the daily passengers for each flight

def feature_pax_2019(features, df):
    
    '''Computes the passengers who travelled by features and flight number and day'''
    
    eval_list = features[:]
    group_features = ['GMT_UPLIFT_DT','OPERATING_FLT_NO']
    prop_features = group_features[:]
    prop_features.extend(eval_list)
    df_flight_sum = df_final.groupby(prop_features)['pax'].sum().reset_index()
    return df_flight_sum, group_features
    
def proportion_formatter(df):
    
    '''Simple function to reformat the tier eligibility table for evaluation joins'''
    
    # format the proportions for the join
    df_proportions = df.stack().reset_index()

    # rename proportion column
    df_proportions = df_proportions.rename({0:'Proportions'}, axis = 1)
    
    return df_proportions

def flight_tier_forecast(df_prop, df_feat, feat_list):
    
    '''Forecasts the number of passengers in each tier for each flight'''
    
    # join the two

    df_total = pd.merge(df_feat, df_prop, how = 'inner', on = feat_list)

    # calculate proportion of each tier in each flight
    df_total['Proportion Numeric'] = df_total['Proportions'].str.replace('%','').astype(float) / 100
    df_total['tier_pax'] = df_total['pax'] * df_total['Proportion Numeric']
    df_total['tier_pax'] = df_total['tier_pax'].values.round()

    return df_total

def eval_table(df_final, df_tot, group_features):

    '''Function to create the evaluation table which compares forecast vs actual'''
    
    tier = 'Lounge_eligibility_tier'

    tier_features = group_features[:]
    tier_features.append(tier)

    df_tier = df_final.groupby(by = tier_features)['pax'].sum().reset_index()
    df_eval = pd.merge(df_tier, df_tot, how = 'inner', on = tier_features)
    
    return  df_eval

def rmse(df_eval):
    
    '''Returns the Root Mean Squared Error of our prediction'''
    
    df_eval['sqrd_resid'] = (df_eval['pax_x'] - df_eval['tier_pax']) ** 2
    std = np.sqrt(df_eval['sqrd_resid'].sum() / df_eval.shape[0])
    
    return std

def evaluation(feat, df_fin, df_test):
    
    '''Function which returns the RMSE of the forecast'''
    
    df_feat, grp_feat = feature_pax_2019(feat, df_fin)
    df_prop_feat = proportion_formatter(df_test)
    df_total = flight_tier_forecast(df_prop_feat, df_feat, feat)
    df_eval = eval_table(df_fin, df_total, grp_feat)
    std = rmse(df_eval)
    return std, df_eval

# %% [markdown]
# #### Combination Function

# %%
def feature_evaluation(feat, df):
    
    df_test = tier_proportions(feat, df)
    result, df_result = evaluation(feat, df, df_test)
    return result, df_result
    
def feature_combination(features):
    
    '''Simple function which returns every possible combination of features'''
    
    nbr_features = len(features)
    feature_comb_list = []
    for nbr in range(1,nbr_features + 1):
        stage_comb = [list(comb) for comb in combinations(features, nbr)]
        feature_comb_list.extend(stage_comb)
        
    return feature_comb_list
    
def combination_evaluation(features, df):
    
    '''A function to test every combination and evaluate its performance'''
    
    results = []
    test_features = feature_combination(features)
    
    # loop through every combination of features and test result
    for feat_comb in test_features:
        rmse, df = feature_evaluation(feat_comb, df)
        results.append([feat_comb,rmse])
        
    # create dataframe of results
    df_result = pd.DataFrame(results, columns = ['feature_combination','RMSE'])
    df_result = df_result.sort_values('RMSE', ascending = True)
    
    return df_result

# %% [markdown]
# ## Data exploration

# %%
df_final.head()
# Out:
#   OPERATING_AIRLINE_CD  OPERATING_FLT_NO GMT_UPLIFT_DT UPLIFT_STN_CD  \
# 0                   BA                57    2019-06-18           LHR
# 1                   BA               247    2019-06-29           LHR
# 2                   BA               766    2019-06-13           LHR
# 3                   BA               556    2019-05-21           LHR
# 4                   BA                27    2019-09-19           LHR
#
#   DISCHARGE_STN_CD BOOKED_CABIN_CD TRAVEL_CABIN_CD BA_PAX_TIER ONEWORLD_TIER  \
# 0              JNB               J               J                      EMER
# 1              GRU               J               J        Gold          EMER
# 2              OSL               C               C      Silver          SAPP
# 3              FCO               M               M                      SAPP
# 4              HKG               F               F     Premier          EMER
#
#   Lounge_eligibility_tier  pax OPG_ALN_CD  OPG_FLT_NO     GMT_PLND_DEP_TS  \
# 0                  Tier 2    1         BA        57.0 2019-06-18 20:25:00
# 1                  Tier 2    1         BA       247.0 2019-06-29 21:25:00
# 2                  Tier 3    7         BA       766.0 2019-06-13 11:55:00
# 3                  Tier 3    1         BA       556.0 2019-05-21 14:45:00
# 4                  Tier 1    2         BA        27.0 2019-09-19 20:45:00
#
#        GMT_ACT_DEP_TS ACT_DEP_STN_CD ACT_DEP_TML_CD PLND_ARR_STN_CD  \
# 0 2019-06-18 20:22:00            LHR              5             JNB
# 1 2019-06-29 21:39:00            LHR              5             GRU
# 2 2019-06-13 12:23:00            LHR              5             OSL
# 3 2019-05-21 14:55:00            LHR              5             FCO
# 4 2019-09-19 20:50:00            LHR              5             HKG
#
#   ACT_ARR_STN_CD IATA_AC_TYP_CD ACT_AC_TYP_CD   ROUTE COUNTRY_CD_x  \
# 0            JNB            744            S4  LHRJNB           ZA
# 1            GRU            77W            G7  LHRGRU           BR
# 2            OSL            321            V6  LHROSL           NO
# 3            FCO            321            V6  LHRFCO           IT
# 4            HKG            77W            G7  LHRHKG           HK
#
#                COUNTRY_NM_x CORP_GEOG_CTRY_GRP_NM_x  \
# 0              South Africa         SOUTHERN AFRICA
# 1                    Brazil           SOUTH AMERICA
# 2                    Norway             SCANDINAVIA
# 3                     Italy           MEDITERRANEAN
# 4  Hong Kong - SAR of China           FAR EAST HUBS
#
#       CORP_GEOG_CONTINENT_NM_x GMT_PLND_DEP COUNTRY_CD_y  \
# 0                       AFRICA   2019-06-18           ZA
# 1  SOUTH AMERICA INC CARIBBEAN   2019-06-29           BR
# 2                EUROPE EXC UK   2019-06-13           NO
# 3                EUROPE EXC UK   2019-05-21           IT
# 4                ASIA FAR EAST   2019-09-19           HK
#
#                COUNTRY_NM_y CORP_GEOG_CTRY_GRP_NM_y  \
# 0              South Africa         SOUTHERN AFRICA
# 1                    Brazil           SOUTH AMERICA
# 2                    Norway             SCANDINAVIA
# 3                     Italy           MEDITERRANEAN
# 4  Hong Kong - SAR of China           FAR EAST HUBS
#
#       CORP_GEOG_CONTINENT_NM_y CTRY_CD       CTRY_NM REGION_CD     REGION_NM  \
# 0                       AFRICA      ZA  South Africa         3         AMESA
# 1  SOUTH AMERICA INC CARIBBEAN      BR        Brazil         4         LACAR
# 2                EUROPE EXC UK      NO        Norway         1        Europe
# 3                EUROPE EXC UK      IT         Italy         1        Europe
# 4                ASIA FAR EAST      HK     Hong Kong         5  Asia Pacific
#
#   SUB_REGION_CD SUB_REGION_NM STN_CD                      STN_NM CITY_CD  \
# 0            AF        Africa    JNB  Johannesburg International     JNB
# 1            SM     S America    GRU       Sao Paulo - Guarulhos     SAO
# 2            NE      N Europe    OSL             Oslo Gardermoen     OSL
# 3            SE      S Europe    FCO              Rome-Fiumicino     ROM
# 4            FE      Far East    HKG    Hong Kong - Chek Lap Kok     HKG
#
#         CITY_NM SUB_CTRY_CD SUB_CTRY_NM  \
# 0  Johannesburg        None        None
# 1     Sao Paulo        None        None
# 2          Oslo        None        None
# 3          Rome        None        None
# 4     Hong Kong        None        None
#
#                                            ICW_TX_PD WB_NB_CAT  \
# 0  2017-02-28 13:42:06.000000,9999-12-31 23:59:59...        WB
# 1  2017-02-28 13:42:06.000000,9999-12-31 23:59:59...        WB
# 2  2017-02-28 13:42:06.000000,9999-12-31 23:59:59...        NB
# 3  2017-02-28 13:42:06.000000,9999-12-31 23:59:59...        NB
# 4  2017-02-28 13:42:06.000000,2018-08-07 05:04:43...        WB
#
#    FIRST_SEATS_QTY  CLUB_SEATS_QTY  PREM_ECONOMY_SEATS_QTY  ECONOMY_SEATS_QTY  \
# 0             14.0            86.0                    30.0              145.0
# 1             14.0            56.0                    44.0              183.0
# 2              0.0            38.0                     0.0              160.0
# 3              0.0            38.0                     0.0              160.0
# 4             14.0            56.0                    44.0              183.0
#
#   country capital            type
# 0     NaN     NaN             NaN
# 1     NaN     NaN             NaN
# 2  Norway    Oslo  countryCapital
# 3   Italy    Rome  countryCapital
# 4     NaN     NaN             NaN

# %% [markdown]
# Things to explore:
# - How does true proportions change by region
# - Where the errors lie, specific regions or any other valuable features we can build
# - Do certain countries have first class and impact on prediction
#
#
# Features to build:

# %%
# City Flag
df_final['capital_city_flag'] = df_final['capital'].apply(lambda x: 'N' if pd.isnull(x) else 'Y')

# %%
features = ['CORP_GEOG_CTRY_GRP_NM_x','time_cat','season','weekend_flag','WB_NB_CAT','capital_city_flag']
features = ['CORP_GEOG_CTRY_GRP_NM_x']

#final_table = combination_evaluation(features, df_final)
result, df_res = feature_evaluation(features, df_final)

# %%
result
# Out:
# 9.365524556442908

# %%
df_res.head()
# Out:
#   GMT_UPLIFT_DT  OPERATING_FLT_NO Lounge_eligibility_tier  pax_x  \
# 0    2019-03-31                 5                  Tier 1     10
# 1    2019-03-31                 5                  Tier 2     15
# 2    2019-03-31                 5                  Tier 3     47
# 3    2019-03-31                 7                  Tier 1     16
# 4    2019-03-31                 7                  Tier 2     20
#
#   CORP_GEOG_CTRY_GRP_NM_x  pax_y Proportions  Proportion Numeric  tier_pax  \
# 0                   JAPAN    241        4.9%               0.049      12.0
# 1                   JAPAN    241        5.3%               0.053      13.0
# 2                   JAPAN    241       20.0%               0.200      48.0
# 3                   JAPAN    300        4.9%               0.049      15.0
# 4                   JAPAN    300        5.3%               0.053      16.0
#
#    sqrd_resid
# 0         4.0
# 1         4.0
# 2         1.0
# 3         1.0
# 4        16.0

# %%
# create sorted data frame
df_sorted = df_res.sort_values('sqrd_resid', ascending = False)

# create daily
df_daily = df_sorted.groupby(['GMT_UPLIFT_DT','Lounge_eligibility_tier'])[['pax_x','tier_pax']].sum().reset_index()

# %% [markdown]
# Things to do:
#
# - Trial machine learning to predict the number of passengers in each tier
# - EDA of different feature to see proportion in tiers by feature

# %% [markdown]
# Can we predict the number of passengers in each tier using attributes of the flight

# %%
df_final.head(2)
# Out:
#   OPERATING_AIRLINE_CD  OPERATING_FLT_NO GMT_UPLIFT_DT UPLIFT_STN_CD  \
# 0                   BA                57    2019-06-18           LHR
# 1                   BA               247    2019-06-29           LHR
#
#   DISCHARGE_STN_CD BOOKED_CABIN_CD TRAVEL_CABIN_CD BA_PAX_TIER ONEWORLD_TIER  \
# 0              JNB               J               J                      EMER
# 1              GRU               J               J        Gold          EMER
#
#   Lounge_eligibility_tier  pax OPG_ALN_CD  OPG_FLT_NO     GMT_PLND_DEP_TS  \
# 0                  Tier 2    1         BA        57.0 2019-06-18 20:25:00
# 1                  Tier 2    1         BA       247.0 2019-06-29 21:25:00
#
#        GMT_ACT_DEP_TS ACT_DEP_STN_CD ACT_DEP_TML_CD PLND_ARR_STN_CD  \
# 0 2019-06-18 20:22:00            LHR              5             JNB
# 1 2019-06-29 21:39:00            LHR              5             GRU
#
#   ACT_ARR_STN_CD IATA_AC_TYP_CD ACT_AC_TYP_CD   ROUTE COUNTRY_CD_x  \
# 0            JNB            744            S4  LHRJNB           ZA
# 1            GRU            77W            G7  LHRGRU           BR
#
#    COUNTRY_NM_x CORP_GEOG_CTRY_GRP_NM_x     CORP_GEOG_CONTINENT_NM_x  \
# 0  South Africa         SOUTHERN AFRICA                       AFRICA
# 1        Brazil           SOUTH AMERICA  SOUTH AMERICA INC CARIBBEAN
#
#   GMT_PLND_DEP COUNTRY_CD_y  COUNTRY_NM_y CORP_GEOG_CTRY_GRP_NM_y  \
# 0   2019-06-18           ZA  South Africa         SOUTHERN AFRICA
# 1   2019-06-29           BR        Brazil           SOUTH AMERICA
#
#       CORP_GEOG_CONTINENT_NM_y CTRY_CD       CTRY_NM REGION_CD REGION_NM  \
# 0                       AFRICA      ZA  South Africa         3     AMESA
# 1  SOUTH AMERICA INC CARIBBEAN      BR        Brazil         4     LACAR
#
#   SUB_REGION_CD SUB_REGION_NM STN_CD                      STN_NM CITY_CD  \
# 0            AF        Africa    JNB  Johannesburg International     JNB
# 1            SM     S America    GRU       Sao Paulo - Guarulhos     SAO
#
#         CITY_NM SUB_CTRY_CD SUB_CTRY_NM  \
# 0  Johannesburg        None        None
# 1     Sao Paulo        None        None
#
#                                            ICW_TX_PD WB_NB_CAT  \
# 0  2017-02-28 13:42:06.000000,9999-12-31 23:59:59...        WB
# 1  2017-02-28 13:42:06.000000,9999-12-31 23:59:59...        WB
#
#    FIRST_SEATS_QTY  CLUB_SEATS_QTY  PREM_ECONOMY_SEATS_QTY  ECONOMY_SEATS_QTY  \
# 0             14.0            86.0                    30.0              145.0
# 1             14.0            56.0                    44.0              183.0
#
#   country capital type capital_city_flag
# 0     NaN     NaN  NaN                 N
# 1     NaN     NaN  NaN                 N

# %%
df_test = df_final.groupby(by = ['OPERATING_AIRLINE_CD','OPERATING_FLT_NO','GMT_UPLIFT_DT','GMT_PLND_DEP_TS','GMT_ACT_DEP_TS','UPLIFT_STN_CD','DISCHARGE_STN_CD',
               'CORP_GEOG_CTRY_GRP_NM_x','REGION_NM','WB_NB_CAT','IATA_AC_TYP_CD','capital','FIRST_SEATS_QTY','CLUB_SEATS_QTY',
               'PREM_ECONOMY_SEATS_QTY','ECONOMY_SEATS_QTY','capital'])['pax'].sum()

# %% [markdown]
# Lets explore the data to see which regions typically have more flights with tier 1 passengers

# %% [markdown]
# There are alot of flights with in Europe with Tier 1 passengers, lets see as a proportion of total flights

# %%
# build dataframe at flight level

flight_feat = ['OPERATING_AIRLINE_CD','OPERATING_FLT_NO','GMT_UPLIFT_DT','GMT_PLND_DEP_TS','GMT_ACT_DEP_TS','UPLIFT_STN_CD','DISCHARGE_STN_CD',
               'CORP_GEOG_CTRY_GRP_NM_x','REGION_NM','WB_NB_CAT','IATA_AC_TYP_CD','capital','FIRST_SEATS_QTY','CLUB_SEATS_QTY',
               'PREM_ECONOMY_SEATS_QTY','ECONOMY_SEATS_QTY','COUNTRY_NM_x']


# Build dataframe with a row for each flight
df_flight = df_final.groupby(flight_feat)['pax'].sum().reset_index()
df_flight = df_flight.rename({'pax':'total_pax'}, axis = 1)

# Build dataframe of number of passengers on each tier
tier_feat = flight_feat[:]
tier_feat.append('Lounge_eligibility_tier')
df_tier = df_final.groupby(tier_feat)['pax'].sum().reset_index()

# %%
# Add in the number of passengers in each tier
test = flight_feat[:]
test.append('pax')
tiers = list(df_final['Lounge_eligibility_tier'].unique())


for tier in tiers:
    df_flight = pd.merge(df_flight, df_tier[df_tier['Lounge_eligibility_tier'] == tier][test], how = 'left', on = flight_feat)
    df_flight = df_flight.rename({'pax': tier + '_pax'}, axis = 1)

# %% [markdown]
# Features to build:
#
# - NB/WB w/wo first
# - Haul
# - Capital City
# - Day of Week
# - Domestic

# %%
df_flight.head(2)
# Out:
#   OPERATING_AIRLINE_CD  OPERATING_FLT_NO GMT_UPLIFT_DT     GMT_PLND_DEP_TS  \
# 0                   BA                 5    2019-03-31 2019-03-31 14:45:00
# 1                   BA                 5    2019-04-01 2019-04-01 14:45:00
#
#        GMT_ACT_DEP_TS UPLIFT_STN_CD DISCHARGE_STN_CD CORP_GEOG_CTRY_GRP_NM_x  \
# 0 2019-03-31 14:51:00           LHR              NRT                   JAPAN
# 1 2019-04-01 14:54:00           LHR              NRT                   JAPAN
#
#       REGION_NM WB_NB_CAT IATA_AC_TYP_CD capital  FIRST_SEATS_QTY  \
# 0  Asia Pacific        WB            789   Tokyo              8.0
# 1  Asia Pacific        WB            789   Tokyo              8.0
#
#    CLUB_SEATS_QTY  PREM_ECONOMY_SEATS_QTY  ECONOMY_SEATS_QTY COUNTRY_NM_x  \
# 0            42.0                    39.0              127.0        Japan
# 1            42.0                    39.0              127.0        Japan
#
#    total_pax  Tier 2_pax  Tier 3_pax  Tier 1_pax  Not eligible_pax
# 0        241        15.0        47.0        10.0             169.0
# 1        225         7.0        43.0        13.0             162.0

# %%
# Feature Creation

# Time of the day 
df_flight['time_cat'] = pd.cut(df_flight['GMT_PLND_DEP_TS'].dt.hour, bins = [0,5,12,17,21,24], labels = ['Night','Morning','Afternoon','Evening','Night'], include_lowest = True, ordered = False)

# Season
df_flight['season'] = pd.cut(df_flight['GMT_PLND_DEP_TS'].dt.month, bins = [0,2,5,8,11,12], labels = ['Winter','Spring','Summer','Autumn','Winter'], include_lowest = True, ordered = False)

# Weekend Flag
df_flight['weekend_flag'] = df_flight['GMT_PLND_DEP_TS'].dt.dayofweek.apply(lambda x: 'Y' if x > 4 else 'N' )

# Month
df_flight['month'] = df_flight['GMT_PLND_DEP_TS'].dt.month

# Day of Week
df_flight['day_of_week'] = df_flight['GMT_PLND_DEP_TS'].dt.dayofweek

# NB/WB w/wo
df_flight['NB_WB_NEW'] = np.where(df_flight['FIRST_SEATS_QTY'] > 0, 'WB w F', np.where(df_flight['WB_NB_CAT'] == 'WB', 'WB w/o', 'NB'))

# Domestic Flag
df_flight['Domestic Flag'] = df_flight['COUNTRY_NM_x'].apply(lambda x: 'Y' if x == 'United Kingdom and Northern Ireland' else 'N')

# Total number of seats

df_flight['Total Seats'] = df_flight['FIRST_SEATS_QTY'] + df_flight['CLUB_SEATS_QTY'] + df_flight['PREM_ECONOMY_SEATS_QTY'] + df_flight['ECONOMY_SEATS_QTY']

# %%
df_flight.head(2)
# Out:
#   OPERATING_AIRLINE_CD  OPERATING_FLT_NO GMT_UPLIFT_DT     GMT_PLND_DEP_TS  \
# 0                   BA                 5    2019-03-31 2019-03-31 14:45:00
# 1                   BA                 5    2019-04-01 2019-04-01 14:45:00
#
#        GMT_ACT_DEP_TS UPLIFT_STN_CD DISCHARGE_STN_CD CORP_GEOG_CTRY_GRP_NM_x  \
# 0 2019-03-31 14:51:00           LHR              NRT                   JAPAN
# 1 2019-04-01 14:54:00           LHR              NRT                   JAPAN
#
#       REGION_NM WB_NB_CAT IATA_AC_TYP_CD capital  FIRST_SEATS_QTY  \
# 0  Asia Pacific        WB            789   Tokyo              8.0
# 1  Asia Pacific        WB            789   Tokyo              8.0
#
#    CLUB_SEATS_QTY  PREM_ECONOMY_SEATS_QTY  ECONOMY_SEATS_QTY COUNTRY_NM_x  \
# 0            42.0                    39.0              127.0        Japan
# 1            42.0                    39.0              127.0        Japan
#
#    total_pax  Tier 2_pax  Tier 3_pax  Tier 1_pax  Not eligible_pax   time_cat  \
# 0        241        15.0        47.0        10.0             169.0  Afternoon
# 1        225         7.0        43.0        13.0             162.0  Afternoon
#
#    season weekend_flag  month  day_of_week NB_WB_NEW Domestic Flag  \
# 0  Spring            Y      3            6    WB w F             N
# 1  Spring            N      4            0    WB w F             N
#
#    Total Seats
# 0        216.0
# 1        216.0

# %% [markdown]
# Our goal is to understand what attributes about flights will help us estimate the % of passengers in each tier of the lounge.
#
# Lets uncover some insights from the flight data.

# %%
print('Total Number of flights: {}'.format(df_flight.shape[0]))
# Out:
# Total Number of flights: 26715

# %%
# Number of passengers by day

df_daily = df_flight.groupby('GMT_UPLIFT_DT')['total_pax','Tier 1_pax','Tier 2_pax','Tier 3_pax','Not eligible_pax'].sum()


df_daily.plot()
plt.tight_layout()
plt.legend(loc = "lower left")
plt.show()
# Out:
# C:\Users\n518899\AppData\Local\Temp\ipykernel_14980\3852271028.py:3: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_daily = df_flight.groupby('GMT_UPLIFT_DT')['total_pax','Tier 1_pax','Tier 2_pax','Tier 3_pax','Not eligible_pax'].sum()

# %% [markdown]
# Daily passenger numbers for each tier don't change much.

# %%
fig, axes = plt.subplots(1,3, figsize = (10,5))
sns.distplot(df_flight['Tier 1_pax'], ax = axes[0])
sns.distplot(df_flight['Tier 2_pax'],ax = axes[1])
sns.distplot(df_flight['Tier 3_pax'],ax = axes[2])
plt.show()
# Out:
# C:\Users\n518899\AppData\Local\Temp\ipykernel_14980\3021373173.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_flight['Tier 1_pax'], ax = axes[0])
# C:\Users\n518899\AppData\Local\Temp\ipykernel_14980\3021373173.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_flight['Tier 2_pax'],ax = axes[1])
# C:\Users\n518899\AppData\Local\Temp\ipykernel_14980\3021373173.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_flight['Tier 3_pax'],ax = axes[2])

# %% [markdown]
# We have built a discrete frequency distribution which shows us the number of passengers by tier and the counts.
#
# All distributions are right skewed at different levels, tier 1 being th emost and tier 3 being the least.
#
# The majority of flights have less than 5 tier 1 passengers, between 0 and 20 tier 2 and between 0 and 50 tier 3 passengers

# %% [markdown]
# ## Tier 1 Relationship with Categorical Variables

# %%
def boxplot_cat(cats, df, target):
    
    '''Builds box plots that compare our target variable tier pax by categorical variable'''
    
    nbr_cat = len(cats)
    columns = 3
    if (nbr_cat % columns) == 0:
        nbr_rows = nbr_cat // columns
    else:
        nbr_rows = nbr_cat // columns + 1

    
    # Build space for plots
    fig, axes = plt.subplots(nbr_rows, columns, figsize = (15,5 * nbr_rows))
    
    # Loop through each cat
    row = 0
    column = 0
    
    for cat in cats:
        if nbr_rows > 1:
            sns.boxplot(x = cat, y = target, data = df, ax = axes[row, column])
        else:
            sns.boxplot(x = cat, y = target, data = df, ax = axes[column])
        
        if column == 0 or column == 1:
            column += 1
        else:
            column = 0
            row += 1
            
    plt.xticks(rotation = 45)       
    plt.tight_layout()
    plt.show()
    
cat_feat = ['REGION_NM','WB_NB_CAT','CORP_GEOG_CTRY_GRP_NM_x','time_cat','season','month','weekend_flag']
boxplot_cat(cat_feat, df_flight, 'Tier 1_pax')

# %% [markdown]
# On initial exploration of categorical features vs tier 1 passengers we can see the follwing:
#
# - Region is a useful predictor of the number of tier 1 passengers and this could be a proxy of long haul vs short haul as europe is the closest region and won't have first class on board.
# - Asia pacific seems to have the highest number of tier 1 pax on average
# - WB_NB_CAT is a useful predictor as this determines again the haul usually as WB are used on long haul and more likely to have first class passengers
# - Time cat seems to show some small relationship where evening flights having more tier 1 passengers vs other periods of the day, this could be due to more long haul flights departing in the evening with first class availability.

# %% [markdown]
# ## Tier 2 Relationship with Categorical Variables

# %%
boxplot_cat(cat_feat, df_flight, 'Tier 2_pax')

# %% [markdown]
# ## Tier 3

# %%
boxplot_cat(cat_feat, df_flight, 'Tier 3_pax')

# %% [markdown]
# ## Machine Learning
#
# ###### To understand variables that are influential in the final prediction

# %%
df = df_flight[:]

# %%
# dtypes

df.dtypes
# Out:
# OPERATING_AIRLINE_CD               object
# OPERATING_FLT_NO                    int64
# GMT_UPLIFT_DT              datetime64[ns]
# GMT_PLND_DEP_TS            datetime64[ns]
# GMT_ACT_DEP_TS             datetime64[ns]
# UPLIFT_STN_CD                      object
# DISCHARGE_STN_CD                   object
# CORP_GEOG_CTRY_GRP_NM_x            object
# REGION_NM                          object
# WB_NB_CAT                          object
# IATA_AC_TYP_CD                     object
# capital                            object
# FIRST_SEATS_QTY                   float64
# CLUB_SEATS_QTY                    float64
# PREM_ECONOMY_SEATS_QTY            float64
# ECONOMY_SEATS_QTY                 float64
# COUNTRY_NM_x                       object
# total_pax                           int64
# Tier 2_pax                        float64
# Tier 3_pax                        float64
# Tier 1_pax                        float64
# Not eligible_pax                  float64
# time_cat                         category
# season                           category
# weekend_flag                       object
# month                               int64
# day_of_week                         int64
# NB_WB_NEW                          object
# Domestic Flag                      object
# Total Seats                       float64
# dtype: object

# %%
# Find the number of missing values
df.isnull().sum()
# Out:
# OPERATING_AIRLINE_CD           0
# OPERATING_FLT_NO               0
# GMT_UPLIFT_DT                  0
# GMT_PLND_DEP_TS                0
# GMT_ACT_DEP_TS                 0
# UPLIFT_STN_CD                  0
# DISCHARGE_STN_CD               0
# CORP_GEOG_CTRY_GRP_NM_x        0
# REGION_NM                      0
# WB_NB_CAT                      0
# IATA_AC_TYP_CD                 0
# capital                        0
# FIRST_SEATS_QTY                0
# CLUB_SEATS_QTY                 0
# PREM_ECONOMY_SEATS_QTY         0
# ECONOMY_SEATS_QTY              0
# COUNTRY_NM_x                   0
# total_pax                      0
# Tier 2_pax                   279
# Tier 3_pax                     2
# Tier 1_pax                 13513
# Not eligible_pax               2
# time_cat                       0
# season                         0
# weekend_flag                   0
# month                          0
# day_of_week                    0
# NB_WB_NEW                      0
# Domestic Flag                  0
# Total Seats                    0
# dtype: int64

# %% [markdown]
# The missing data in Tier pax columns are due to the fact that those airlines have no passengers in that tier and therefore has null values. We can easily solve this by filling it with 0.

# %%
df[['Tier 2_pax','Tier 3_pax','Tier 1_pax','Not eligible_pax']] = df[['Tier 2_pax','Tier 3_pax','Tier 1_pax','Not eligible_pax']].fillna(0)

# %%
# Total count of missing values
df.isnull().sum().sum()
# Out:
# 0

# %%
df.head(2)
# Out:
#   OPERATING_AIRLINE_CD  OPERATING_FLT_NO GMT_UPLIFT_DT     GMT_PLND_DEP_TS  \
# 0                   BA                 5    2019-03-31 2019-03-31 14:45:00
# 1                   BA                 5    2019-04-01 2019-04-01 14:45:00
#
#        GMT_ACT_DEP_TS UPLIFT_STN_CD DISCHARGE_STN_CD CORP_GEOG_CTRY_GRP_NM_x  \
# 0 2019-03-31 14:51:00           LHR              NRT                   JAPAN
# 1 2019-04-01 14:54:00           LHR              NRT                   JAPAN
#
#       REGION_NM WB_NB_CAT IATA_AC_TYP_CD capital  FIRST_SEATS_QTY  \
# 0  Asia Pacific        WB            789   Tokyo              8.0
# 1  Asia Pacific        WB            789   Tokyo              8.0
#
#    CLUB_SEATS_QTY  PREM_ECONOMY_SEATS_QTY  ECONOMY_SEATS_QTY COUNTRY_NM_x  \
# 0            42.0                    39.0              127.0        Japan
# 1            42.0                    39.0              127.0        Japan
#
#    total_pax  Tier 2_pax  Tier 3_pax  Tier 1_pax  Not eligible_pax   time_cat  \
# 0        241        15.0        47.0        10.0             169.0  Afternoon
# 1        225         7.0        43.0        13.0             162.0  Afternoon
#
#    season weekend_flag  month  day_of_week NB_WB_NEW Domestic Flag  \
# 0  Spring            Y      3            6    WB w F             N
# 1  Spring            N      4            0    WB w F             N
#
#    Total Seats
# 0        216.0
# 1        216.0

# %%
cat_feat = ['COUNTRY_NM_x','Domestic Flag','time_cat','day_of_week','IATA_AC_TYP_CD']
num_feat = ['Total Seats']
targets = ['Tier 1_pax','Tier 2_pax','Tier 3_pax','Not eligible_pax']
target1 = ['Tier 1_pax']
target2 = ['Tier 2_pax']
target3 = ['Tier 3_pax']
targetna = ['Not eligible_pax']

y = df[targets]
X = df[cat_feat]

X_train, X_test, y_train, y_test = train_test_split(
X, y, test_size=0.33, random_state=42)

ohs = OneHotEncoder(handle_unknown = 'ignore', sparse = False)
X_train_adj = ohs.fit_transform(X_train)
X_test_adj = ohs.transform(X_test)

lg = LinearRegression()
lg.fit(X_train_adj, y_train)
print(lg.score(X_test_adj, y_test))

# achieves a score of 0.5454 (adjusted R), 1.00 being a perfect prediction
# Out:
# 0.5453898019624628

# %%
y_pred = lg.predict(X_test_adj)
mse = mean_squared_error(y_test,y_pred)
rmse = sqrt(mse)
print(rmse)
# Out:
# 13.70944880477969

# %%
k = []
for i in cat_feat:
    k.append(i)
for j in targets:
    k.append(j)

# %% [markdown]
# ## Conclusions from linear regression ML
#
# - Our linear regression model, `lg`, predicts the number of tier 1 passengers very well, this is for a couple of reasons:
#     - passenger numbers are small, while maintaining the sample size, so the model has a narrower window from which to predict pax
#     - the available features show more differentiation within tier 1 and so are more helpful for the training of the model
#
# - We found a test/train split of 0.33 produced the best outcome
#
# - Through extensive testing we settled on 5 defining features:
#     - country of destination `COUNTRY_NM_x`
#     - domestic flight or not `domestic flag`
#     - time of day `time_cat`
#     - day of the weel `day_of_week`
#     - aircraft type `IATA_AC_TYP_CD`
#
# - These produced the most accurate predictions without overfitting the data

# %% [markdown]
# # Final pieces and notes

# %%
df_flight.head()

# %%
df_lookup = df_flight[k]
df_lookup.head()
# Out:
#   COUNTRY_NM_x Domestic Flag   time_cat  day_of_week IATA_AC_TYP_CD  \
# 0        Japan             N  Afternoon            6            789
# 1        Japan             N  Afternoon            0            789
# 2        Japan             N  Afternoon            1            789
# 3        Japan             N  Afternoon            2            789
# 4        Japan             N  Afternoon            3            789
#
#    Tier 1_pax  Tier 2_pax  Tier 3_pax  Not eligible_pax
# 0        10.0        15.0        47.0             169.0
# 1        13.0         7.0        43.0             162.0
# 2        15.0         5.0        40.0             164.0
# 3        10.0        13.0        29.0             165.0
# 4         9.0        17.0        36.0             148.0

# %% [markdown]
# #### To conclude
#
# We didn't reach as far as we would have liked in this challenge, mainly because of a lack of time. We did a fair bit of research into the data, but more could have definitely been done further outside of the columns that were put in front of us, this might have allowed us to pick up other influencing factors that would be useful for a predictive model.
#
#
# The basic linear regression model we created was sufficient for collecting insights on what features were most useful, but it's not really effective enough for accurate predictions relied on for business decisions. Had we spent more time on the analysis, we would have developed this analysis further, perhaps dipping our toes in some unsupervised machine learning to try and draw out some useful clusters within the data. More data would also be helpful for the training of the model as it would have more 'practice', and might find it easier to pick up any underlying trends.
#
#
# Thanks for your time and we hope that you find some ideas and interest in our workthrough!
#
# Dhruv (mostly!) and Archie
